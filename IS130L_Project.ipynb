# %% [markdown]
# <a href="https://colab.research.google.com/github/Drewww17/Pineapple-Detection-Using-YOLOv-Algorithm/blob/main/IS130L_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch, platform
print("CUDA available:", torch.cuda.is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
print("Python:", platform.python_version())
# Out:
# CUDA available: True
# GPU: Tesla T4
# Python: 3.12.11

# %%
import torch, platform
print("CUDA available:", torch.cuda.is_is_available())
print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
print("Python:", platform.python_version())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2619390838.py in <cell line: 0>()
#       1 import torch, platform
# ----> 2 print("CUDA available:", torch.cuda.is_is_available())
#       3 print("GPU:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
#       4 print("Python:", platform.python_version())
#
# AttributeError: module 'torch.cuda' has no attribute 'is_is_available'

# %%
# !pip install -q ultralytics roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 90.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 135.0 MB/s eta 0:00:00

# %%
from roboflow import Roboflow

WORKSPACE = "is130ldatamining-2kxwq"
PROJECT   = "pineapple-maturity-project-9pdpa"
VERSION   = 1

rf = Roboflow(api_key="7VNBGMkBglxp1pekgkJG")
project = rf.workspace(WORKSPACE).project(PROJECT)
dataset = project.version(VERSION).download("yolov8")

print("Dataset location:", dataset.location)  # e.g. /content/pineapple-maturity-project-9pdpa-1
print("Data YAML:", dataset.location + "/data.yaml")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Pineapple-Maturity-Project-1 in yolov8:: 100%|██████████| 1644/1644 [00:00<00:00, 5160.50it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dataset location: /content/Pineapple-Maturity-Project-1
# Data YAML: /content/Pineapple-Maturity-Project-1/data.yaml

# %%
# !ls -R /content/Pineapple-Maturity-Project-1
# Out:
# /content/Pineapple-Maturity-Project-1:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
#
# /content/Pineapple-Maturity-Project-1/test:
# images	labels
#
# /content/Pineapple-Maturity-Project-1/test/images:
# 1605515851pineapple-fruits_medium_jpg.rf.927cf3b950997cb191316d353a95b8d2.jpg
# 89494720-summer-fruits-for-healthy-lifestyle-pineapple-fruit-vector-illustration-cartoon-flat-icon-isolated-o_jpg.rf.b21949d61bd3e5601825979628367030.jpg
# ananas_000_jpg.rf.1484ab342c8bcb16abcbaa1d463c635f.jpg
# Futaba-Mini-Pineapple-Fruit-Seeds-SDL433330964-1-34ab6_jpeg_jpg.rf.158dbcfb4631511f6b06165cce61c358.jpg
# image15_jpeg_jpg.rf.a75ce8d01e7db3e86ffafb90ce552ec1.jpg
# images107_jpg.rf.1719850de384bf0829970965d3431175.jpg
# images150_jpg.rf.340b7e0ffda751935b253ee58c8fe0e8.jpg
# images165_jpg.rf.6072d5e93af771b0372a0d08901a2246.jpg
# images320_jpg.rf.71623ee28cf4d1f9d82374099125d1b6.jpg
# images342_jpg.rf.9b529c71cacf410342ad03fd08af9a7f.jpg
# ...

# %%
# List only the top-level items
# !ls /content/Pineapple-Maturity-Project-1

# List train, valid, (and test if exists)
# !ls /content/Pineapple-Maturity-Project-1/train
# !ls /content/Pineapple-Maturity-Project-1/valid
# !ls /content/Pineapple-Maturity-Project-1/test
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
# images	labels
# images	labels
# images	labels

# %% [markdown]
# ### Implementing YOLOv9
#
# Now we will proceed with implementing YOLOv9 using the downloaded dataset.
#
# **Step 1: Find and clone YOLOv9 implementation**
#
# We will clone a reputable YOLOv9 repository from GitHub.

# %%
# Clone the YOLOv9 repository
# !git clone https://github.com/WongKinYiu/yolov9.git
# %cd yolov9
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 781, done.
# remote: Total 781 (delta 0), reused 0 (delta 0), pack-reused 781 (from 1)
# Receiving objects: 100% (781/781), 3.27 MiB | 13.56 MiB/s, done.
# Resolving deltas: 100% (330/330), done.
# /content/yolov9

# %% [markdown]
# **Step 2: Install dependencies**
#
# Install any additional libraries or dependencies required by the YOLOv9 implementation.

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 82.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Step 3: Prepare configuration**
#
# Update the configuration files for YOLOv9 to point to your dataset and set training parameters. This typically involves modifying a data configuration file (like a `.yaml` file) within the cloned repository to specify the paths to your train, validation, and test image and label directories, as well as the number of classes and class names.
#
# You will need to locate the appropriate configuration file within the `yolov9` directory (it might be in a `data` or `cfg` subdirectory) and update the paths.
#
# For example, you might need to modify a file like `data/coco.yaml` or create a new one based on it, pointing to your dataset location: `/content/Pineapple-Maturity-Project-1`.

# %% [markdown]
# **Step 4: Train the model**
#
# Run the training script provided by the YOLOv9 implementation, using your dataset. The exact command will depend on the YOLOv9 repository's structure, but it will likely involve running a Python script (e.g., `train.py`) and specifying the data configuration file and model configuration.
#
# You will need to check the documentation or examples in the cloned YOLOv9 repository for the specific training command. It might look something like this:
#
# `!python train.py --data /content/Pineapple-Maturity-Project-1/data.yaml --cfg models/detect/yolov9.yaml --weights '' --imgsz 640 --epochs 100 --batch-size 16`
#
# *   `--data`: path to your dataset's data.yaml file
# *   `--cfg`: path to the YOLOv9 model configuration file
# *   `--weights`: path to pre-trained weights (use '' for training from scratch)
# *   `--imgsz`: image size for training
# *   `--epochs`: number of training epochs
# *   `--batch-size`: batch size for training

# %% [markdown]
# **Step 5: Evaluate the model**
#
# Evaluate the performance of the trained YOLOv9 model on the test set. This typically involves running an evaluation script (e.g., `test.py` or `val.py`) provided by the YOLOv9 implementation, using the trained model weights and the test dataset.
#
# The command might look something like this:
#
# `!python test.py --data /content/Pineapple-Maturity-Project-1/data.yaml --cfg models/detect/yolov9.yaml --weights runs/train/exp/weights/best.pt --imgsz 640`
#
# *   `--data`: path to your dataset's data.yaml file
# *   `--cfg`: path to the YOLOv9 model configuration file
# *   `--weights`: path to the trained model weights (replace `runs/train/exp/weights/best.pt` with the actual path to your best weights)
# *   `--imgsz`: image size for evaluation

# %% [markdown]
# **Step 6: Finish task**
#
# Summarize the process and results, and suggest next steps like inference on new images.

# %%
# !pip install -q ultralytics roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 86.7 MB/s eta 0:00:00

# %%
from roboflow import Roboflow

WORKSPACE = "is130ldatamining-2kxwq"
PROJECT   = "pineapple-maturity-project-9pdpa"
VERSION   = 1

rf = Roboflow(api_key="7VNBGMkBglxp1pekgkJG")
project = rf.workspace(WORKSPACE).project(PROJECT)
dataset = project.version(VERSION).download("yolov8")

print("Dataset location:", dataset.location)  # e.g. /content/pineapple-maturity-project-9pdpa-1
print("Data YAML:", dataset.location + "/data.yaml")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Pineapple-Maturity-Project-1 in yolov8:: 100%|██████████| 1644/1644 [00:00<00:00, 5581.13it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Dataset location: /content/Pineapple-Maturity-Project-1
# Data YAML: /content/Pineapple-Maturity-Project-1/data.yaml

# %%
# !ls -R /content/Pineapple-Maturity-Project-1
# Out:
# /content/Pineapple-Maturity-Project-1:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
#
# /content/Pineapple-Maturity-Project-1/test:
# images	labels
#
# /content/Pineapple-Maturity-Project-1/test/images:
# 1605515851pineapple-fruits_medium_jpg.rf.927cf3b950997cb191316d353a95b8d2.jpg
# 89494720-summer-fruits-for-healthy-lifestyle-pineapple-fruit-vector-illustration-cartoon-flat-icon-isolated-o_jpg.rf.b21949d61bd3e5601825979628367030.jpg
# ananas_000_jpg.rf.1484ab342c8bcb16abcbaa1d463c635f.jpg
# Futaba-Mini-Pineapple-Fruit-Seeds-SDL433330964-1-34ab6_jpeg_jpg.rf.158dbcfb4631511f6b06165cce61c358.jpg
# image15_jpeg_jpg.rf.a75ce8d01e7db3e86ffafb90ce552ec1.jpg
# images107_jpg.rf.1719850de384bf0829970965d3431175.jpg
# images150_jpg.rf.340b7e0ffda751935b253ee58c8fe0e8.jpg
# images165_jpg.rf.6072d5e93af771b0372a0d08901a2246.jpg
# images320_jpg.rf.71623ee28cf4d1f9d82374099125d1b6.jpg
# images342_jpg.rf.9b529c71cacf410342ad03fd08af9a7f.jpg
# ...

# %%
# List only the top-level items
# !ls /content/Pineapple-Maturity-Project-1

# List train, valid, (and test if exists)
# !ls /content/Pineapple-Maturity-Project-1/train
# !ls /content/Pineapple-Maturity-Project-1/valid
# !ls /content/Pineapple-Maturity-Project-1/test
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
# images	labels
# images	labels
# images	labels
